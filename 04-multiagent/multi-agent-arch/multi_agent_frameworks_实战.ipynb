# %% [markdown]
# # 课程索引
#
# 本目录全部 Notebook 已统一编号 **01–09**，完整讲课顺序见 [`README.md`](README.md)。
#
# | # | Notebook | 内容 |
# |---|----------|------|
# | 01 | [`01_multi_agent_arch_demo.ipynb`](01_multi_agent_arch_demo.ipynb) | 多 Agent 架构模式（Pipeline / Blackboard 等） |
# | 02 | [`02_hierarchical_multi_agent_demo.ipynb`](02_hierarchical_multi_agent_demo.ipynb) | 分层协作与 HITL |
# | 03 | [`03_环境初始化与MAS基础.ipynb`](03_环境初始化与MAS基础.ipynb) | 依赖、环境变量、MAS 概论 |
# | 04 | [`04_autogen_实战.ipynb`](04_autogen_实战.ipynb) | AutoGen 实战 |
# | 05 | [`05_crewai_实战.ipynb`](05_crewai_实战.ipynb) | CrewAI 实战 |
# | 06 | [`06_agentic_rag_与框架对比.ipynb`](06_agentic_rag_与框架对比.ipynb) | LangGraph + Agentic RAG |
# | 07 | [`07_课堂练习.ipynb`](07_课堂练习.ipynb) | 练习 A / B / C |
# | 08 | [`08_工程化与总结.ipynb`](08_工程化与总结.ipynb) | 工程化要点与总结 |
# | 09 | [`09_agent_ops_langsmith_demo.ipynb`](09_agent_ops_langsmith_demo.ipynb) | Agent Ops & LangSmith |
#
# 请从 **01** 开始按顺序学习。
